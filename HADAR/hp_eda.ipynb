# %% [markdown]
# # EDA - House Price Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
housePrice = pd.read_csv('HousePrice_clean.csv')

# %%
import urllib.request, json
with urllib.request.urlopen('https://www.openml.org/d/42165/json') as url:
    data = json.loads(url.read().decode())

# %%
data
# Out:
# {'data_id': '42165',
#  'name': 'house_prices',
#  'exact_name': 'house_prices',
#  'version': 1,
#  'version_label': '0.1',
#  'description': "Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.\n\nWith 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.\n\nMSSubClass: Identifies the type of dwelling involved in the sale.\t\n\n        20\t1-STORY 1946 & NEWER ALL STYLES\n        30\t1-STORY 1945 & OLDER\n        40\t1-STORY W/FINISHED ATTIC ALL AGES\n        45\t1-1/2 STORY - UNFINISHED ALL AGES\n        50\t1-1/2 STORY FINISHED ALL AGES\n        60\t2-STORY 1946 & NEWER\n        70\t2-STORY 1945 & OLDER\n        75\t2-1/2 STORY ALL AGES\n        80\tSPLIT OR MULTI-LEVEL\n        85\tSPLIT FOYER\n        90\tDUPLEX - ALL STYLES AND AGES\n       120\t1-STORY PUD (Planned Unit Development) - 1946 & NEWER\n       150\t1-1/2 STORY PUD - ALL AGES\n       160\t2-STORY PUD - 1946 & NEWER\n       180\tPUD - MULTILEVEL - INCL SPLIT LEV/FOYER\n       190\t2 FAMILY CONVERSION - ALL STYLES AND AGES\n\nMSZoning: Identifies the general zoning classification of the sale.\n\t\t\n       A\tAgriculture\n       C\tCommercial\n       FV\tFloating Village Residential\n       I\tIndustrial\n       RH\tResidential High Density\n       RL\tResidential Low Density\n       RP\tResidential Low Density Park \n       RM\tResidential Medium Density\n\t\nLotFrontage: Linear feet of street connected to property\n\nLotArea: Lot size in square feet\n\nStreet: Type of road access to property\n\n       Grvl\tGravel\t\n       Pave\tPaved\n       \t\nAlley: Type of alley access to property\n\n       Grvl\tGravel\n       Pave\tPaved\n       NA \tNo alley access\n\t\t\nLotShape: General shape of property\n\n       Reg\tRegular\t\n       IR1\tSlightly irregular\n       IR2\tModerately Irregular\n       IR3\tIrregular\n       \nLandContour: Flatness of the property\n\n       Lvl\tNear Flat/Level\t\n       Bnk\tBanked - Quick and significant rise from street grade to building\n       HLS\tHillside - Significant slope from side to side\n       Low\tDepression\n\t\t\nUtilities: Type of utilities available\n\t\t\n       AllPub\tAll public Utilities (E,G,W,& S)\t\n       NoSewr\tElectricity, Gas, and Water (Septic Tank)\n       NoSeWa\tElectricity and Gas Only\n       ELO\tElectricity only\t\n\t\nLotConfig: Lot configuration\n\n       Inside\tInside lot\n       Corner\tCorner lot\n       CulDSac\tCul-de-sac\n       FR2\tFrontage on 2 sides of property\n       FR3\tFrontage on 3 sides of property\n\t\nLandSlope: Slope of property\n\t\t\n       Gtl\tGentle slope\n       Mod\tModerate Slope\t\n       Sev\tSevere Slope\n\t\nNeighborhood: Physical locations within Ames city limits\n\n       Blmngtn\tBloomington Heights\n       Blueste\tBluestem\n       BrDale\tBriardale\n       BrkSide\tBrookside\n       ClearCr\tClear Creek\n       CollgCr\tCollege Creek\n       Crawfor\tCrawford\n       Edwards\tEdwards\n       Gilbert\tGilbert\n       IDOTRR\tIowa DOT and Rail Road\n       MeadowV\tMeadow Village\n       Mitchel\tMitchell\n       Names\tNorth Ames\n       NoRidge\tNorthridge\n       NPkVill\tNorthpark Villa\n       NridgHt\tNorthridge Heights\n       NWAmes\tNorthwest Ames\n       OldTown\tOld Town\n       SWISU\tSouth & West of Iowa State University\n       Sawyer\tSawyer\n       SawyerW\tSawyer West\n       Somerst\tSomerset\n       StoneBr\tStone Brook\n       Timber\tTimberland\n       Veenker\tVeenker\n\t\t\t\nCondition1: Proximity to various conditions\n\t\n       Artery\tAdjacent to arterial street\n       Feedr\tAdjacent to feeder street\t\n       Norm\tNormal\t\n       RRNn\tWithin 200' of North-South Railroad\n       RRAn\tAdjacent to North-South Railroad\n       PosN\tNear positive off-site feature--park, greenbelt, etc.\n  ...
#  'format': 'arff',
#  'uploader': 'Thomas Schmitt',
#  'uploader_id': 3422,
#  'visibility': 'public',
#  'creator': '"OkCupid"',
#  'contributor': None,
#  'date': '2019-10-04 12:57:32',
#  'update_comment': None,
#  'last_update': '2019-10-04 12:57:32',
#  'licence': 'NA',
#  'status': 'active',
#  'error_message': None,
#  'url': 'https://www.openml.org/data/download/21754539/dataset',
#  'default_target_attribute': 'SalePrice',
#  'row_id_attribute': None,
#  'ignore_attribute': None,
#  'runs': 0,
#  'suggest': {'input': ['house_prices',
#    "Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence. With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home. MSSubClass: Identifi "],
#   'weight': 5},
#  'qualities': {'NumberOfInstances': 1460,
#   'NumberOfFeatures': 81,
#   'NumberOfClasses': 0,
#   'NumberOfMissingValues': 6965,
#   'NumberOfInstancesWithMissingValues': 1460,
#   'NumberOfNumericFeatures': 38,
#   'NumberOfSymbolicFeatures': 0,
#   'MajorityClassSize': None,
#   'MinAttributeEntropy': None,
#   'Quartile2SkewnessOfNumericAtts': 1.3716584890250498,
#   'MaxAttributeEntropy': None,
#   'MinKurtosisOfNumericAtts': -1.2722451924730418,
#   'PercentageOfBinaryFeatures': 0,
#   'Quartile2StdDevOfNumericAtts': 41.23893896917039,
#   'MaxKurtosisOfNumericAtts': 701.0033422800799,
#   'MinMeansOfNumericAtts': 0.057534246575342445,
#   'PercentageOfInstancesWithMissingValues': 100,
#   'Quartile3AttributeEntropy': None,
#   'MaxMeansOfNumericAtts': 180921.19589041095,
#   'MinMutualInformation': None,
#   'PercentageOfMissingValues': 5.889565364451209,
#   'Quartile3KurtosisOfNumericAtts': 16.66069827396739,
#   'MaxMutualInformation': None,
#   'MinNominalAttDistinctValues': None,
#   'PercentageOfNumericFeatures': 46.913580246913575,
#   'Quartile3MeansOfNumericAtts': 812.2323630136987,
#   'MaxNominalAttDistinctValues': None,
#   'MinSkewnessOfNumericAtts': -0.6494146238714703,
#   'PercentageOfSymbolicFeatures': 0,
#   'Quartile3MutualInformation': None,
#   'MaxSkewnessOfNumericAtts': 24.476794188824,
#   'MinStdDevOfNumericAtts': 0.22033819838402977,
#   'Quartile1AttributeEntropy': None,
#   'Quartile3SkewnessOfNumericAtts': 3.3432546022725926,
#   'MaxStdDevOfNumericAtts': 79442.50288288663,
#   'MinorityClassPercentage': None,
#   'Quartile1KurtosisOfNumericAtts': -0.40766725564600836,
#   'Quartile3StdDevOfNumericAtts': 395.34330587301736,
#   'MeanAttributeEntropy': None,
#   'MinorityClassSize': None,
#   'Quartile1MeansOfNumericAtts': 3.2738013698630284,
#   'StdvNominalAttDistinctValues': None,
#   'MeanKurtosisOfNumericAtts': 39.49810611557981,
#   'NumberOfBinaryFeatures': 0,
#   'Quartile1MutualInformation': None,
#   'MeanMeansOfNumericAtts': 5426.873529570761,
#   'Quartile1SkewnessOfNumericAtts': 0.21198726285736386,
#   'AutoCorrelation': -80645.68265935572,
#   'MeanMutualInformation': None,
#   'Quartile1StdDevOfNumericAtts': 1.2742711745922621,
#   'ClassEntropy': None,
#   'MeanNoiseToSignalRatio': None,
#   'Quartile2AttributeEntropy': None,
#   'Dimensionality': 0.05547945205479452,
#   'MeanNominalAttDistinctValues': None,
#   'Quartile2KurtosisOfNumericAtts': 2.611912753447567,
#   'EquivalentNumberOfAtts': None,
#   'MeanSkewnessOfNumericAtts': 2.9668029017649626,
#   'Quartile2MeansOfNumericAtts': 46.604794520547955,
#   'MajorityClassPercentage': None,
#   'MeanStdDevOfNumericAtts': 2478.001658781411,
#   'Quartile2MutualInformation': None},
#  'tags': [],
#  'features': [{'name': 'SalePrice',
#    'index': '80',
#    'type': 'numeric',
#    'distinct': '663',
#    'missing': '0',
#    'target': '1',
#    'min': '34900',
#    'max': '755000',
#    'mean': '180921',
#    'stdev': '79443'},
#   {'name': 'Id',
#    'index': '0',
#    'type': 'numeric',
#    'distinct': '1460',
#    'missing': '0',
#    'min': '1',
#    'max': '1460',
#    'mean': '731',
#    'stdev': '422'},
#   {'name': 'MSSubClass',
#    'index': '1',
#    'type': 'numeric',
#    'distinct': '15',
#    'missing': '0',
#    'min': '20',
#    'max': '190',
#    'mean': '57',
#    'stdev': '42'},
#   {'name': 'MSZoning',
#    'index': '2',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '0'},
#   {'name': 'LotFrontage',
#    'index': '3',
#    'type': 'numeric',
#    'distinct': '110',
#    'missing': '259',
#    'min': '21',
#    'max': '313',
#    'mean': '70',
#    'stdev': '24'},
#   {'name': 'LotArea',
#    'index': '4',
#    'type': 'numeric',
#    'distinct': '1073',
#    'missing': '0',
#    'min': '1300',
#    'max': '215245',
#    'mean': '10517',
#    'stdev': '9981'},
#   {'name': 'Street',
#    'index': '5',
#    'type': 'string',
#    'distinct': '2',
#    'missing': '0'},
#   {'name': 'Alley',
#    'index': '6',
#    'type': 'string',
#    'distinct': '2',
#    'missing': '1369'},
#   {'name': 'LotShape',
#    'index': '7',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '0'},
#   {'name': 'LandContour',
#    'index': '8',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '0'},
#   {'name': 'Utilities',
#    'index': '9',
#    'type': 'string',
#    'distinct': '2',
#    'missing': '0'},
#   {'name': 'LotConfig',
#    'index': '10',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '0'},
#   {'name': 'LandSlope',
#    'index': '11',
#    'type': 'string',
#    'distinct': '3',
#    'missing': '0'},
#   {'name': 'Neighborhood',
#    'index': '12',
#    'type': 'string',
#    'distinct': '25',
#    'missing': '0'},
#   {'name': 'Condition1',
#    'index': '13',
#    'type': 'string',
#    'distinct': '9',
#    'missing': '0'},
#   {'name': 'Condition2',
#    'index': '14',
#    'type': 'string',
#    'distinct': '8',
#    'missing': '0'},
#   {'name': 'BldgType',
#    'index': '15',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '0'},
#   {'name': 'HouseStyle',
#    'index': '16',
#    'type': 'string',
#    'distinct': '8',
#    'missing': '0'},
#   {'name': 'OverallQual',
#    'index': '17',
#    'type': 'numeric',
#    'distinct': '10',
#    'missing': '0',
#    'min': '1',
#    'max': '10',
#    'mean': '6',
#    'stdev': '1'},
#   {'name': 'OverallCond',
#    'index': '18',
#    'type': 'numeric',
#    'distinct': '9',
#    'missing': '0',
#    'min': '1',
#    'max': '9',
#    'mean': '6',
#    'stdev': '1'},
#   {'name': 'YearBuilt',
#    'index': '19',
#    'type': 'numeric',
#    'distinct': '112',
#    'missing': '0',
#    'min': '1872',
#    'max': '2010',
#    'mean': '1971',
#    'stdev': '30'},
#   {'name': 'YearRemodAdd',
#    'index': '20',
#    'type': 'numeric',
#    'distinct': '61',
#    'missing': '0',
#    'min': '1950',
#    'max': '2010',
#    'mean': '1985',
#    'stdev': '21'},
#   {'name': 'RoofStyle',
#    'index': '21',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '0'},
#   {'name': 'RoofMatl',
#    'index': '22',
#    'type': 'string',
#    'distinct': '8',
#    'missing': '0'},
#   {'name': 'Exterior1st',
#    'index': '23',
#    'type': 'string',
#    'distinct': '15',
#    'missing': '0'},
#   {'name': 'Exterior2nd',
#    'index': '24',
#    'type': 'string',
#    'distinct': '16',
#    'missing': '0'},
#   {'name': 'MasVnrType',
#    'index': '25',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '8'},
#   {'name': 'MasVnrArea',
#    'index': '26',
#    'type': 'numeric',
#    'distinct': '327',
#    'missing': '8',
#    'min': '0',
#    'max': '1600',
#    'mean': '104',
#    'stdev': '181'},
#   {'name': 'ExterQual',
#    'index': '27',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '0'},
#   {'name': 'ExterCond',
#    'index': '28',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '0'},
#   {'name': 'Foundation',
#    'index': '29',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '0'},
#   {'name': 'BsmtQual',
#    'index': '30',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '37'},
#   {'name': 'BsmtCond',
#    'index': '31',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '37'},
#   {'name': 'BsmtExposure',
#    'index': '32',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '38'},
#   {'name': 'BsmtFinType1',
#    'index': '33',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '37'},
#   {'name': 'BsmtFinSF1',
#    'index': '34',
#    'type': 'numeric',
#    'distinct': '637',
#    'missing': '0',
#    'min': '0',
#    'max': '5644',
#    'mean': '444',
#    'stdev': '456'},
#   {'name': 'BsmtFinType2',
#    'index': '35',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '38'},
#   {'name': 'BsmtFinSF2',
#    'index': '36',
#    'type': 'numeric',
#    'distinct': '144',
#    'missing': '0',
#    'min': '0',
#    'max': '1474',
#    'mean': '47',
#    'stdev': '161'},
#   {'name': 'BsmtUnfSF',
#    'index': '37',
#    'type': 'numeric',
#    'distinct': '780',
#    'missing': '0',
#    'min': '0',
#    'max': '2336',
#    'mean': '567',
#    'stdev': '442'},
#   {'name': 'TotalBsmtSF',
#    'index': '38',
#    'type': 'numeric',
#    'distinct': '721',
#    'missing': '0',
#    'min': '0',
#    'max': '6110',
#    'mean': '1057',
#    'stdev': '439'},
#   {'name': 'Heating',
#    'index': '39',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '0'},
#   {'name': 'HeatingQC',
#    'index': '40',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '0'},
#   {'name': 'CentralAir',
#    'index': '41',
#    'type': 'string',
#    'distinct': '2',
#    'missing': '0'},
#   {'name': 'Electrical',
#    'index': '42',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '1'},
#   {'name': '1stFlrSF',
#    'index': '43',
#    'type': 'numeric',
#    'distinct': '753',
#    'missing': '0',
#    'min': '334',
#    'max': '4692',
#    'mean': '1163',
#    'stdev': '387'},
#   {'name': '2ndFlrSF',
#    'index': '44',
#    'type': 'numeric',
#    'distinct': '417',
#    'missing': '0',
#    'min': '0',
#    'max': '2065',
#    'mean': '347',
#    'stdev': '437'},
#   {'name': 'LowQualFinSF',
#    'index': '45',
#    'type': 'numeric',
#    'distinct': '24',
#    'missing': '0',
#    'min': '0',
#    'max': '572',
#    'mean': '6',
#    'stdev': '49'},
#   {'name': 'GrLivArea',
#    'index': '46',
#    'type': 'numeric',
#    'distinct': '861',
#    'missing': '0',
#    'min': '334',
#    'max': '5642',
#    'mean': '1515',
#    'stdev': '525'},
#   {'name': 'BsmtFullBath',
#    'index': '47',
#    'type': 'numeric',
#    'distinct': '4',
#    'missing': '0',
#    'min': '0',
#    'max': '3',
#    'mean': '0',
#    'stdev': '1'},
#   {'name': 'BsmtHalfBath',
#    'index': '48',
#    'type': 'numeric',
#    'distinct': '3',
#    'missing': '0',
#    'min': '0',
#    'max': '2',
#    'mean': '0',
#    'stdev': '0'},
#   {'name': 'FullBath',
#    'index': '49',
#    'type': 'numeric',
#    'distinct': '4',
#    'missing': '0',
#    'min': '0',
#    'max': '3',
#    'mean': '2',
#    'stdev': '1'},
#   {'name': 'HalfBath',
#    'index': '50',
#    'type': 'numeric',
#    'distinct': '3',
#    'missing': '0',
#    'min': '0',
#    'max': '2',
#    'mean': '0',
#    'stdev': '1'},
#   {'name': 'BedroomAbvGr',
#    'index': '51',
#    'type': 'numeric',
#    'distinct': '8',
#    'missing': '0',
#    'min': '0',
#    'max': '8',
#    'mean': '3',
#    'stdev': '1'},
#   {'name': 'KitchenAbvGr',
#    'index': '52',
#    'type': 'numeric',
#    'distinct': '4',
#    'missing': '0',
#    'min': '0',
#    'max': '3',
#    'mean': '1',
#    'stdev': '0'},
#   {'name': 'KitchenQual',
#    'index': '53',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '0'},
#   {'name': 'TotRmsAbvGrd',
#    'index': '54',
#    'type': 'numeric',
#    'distinct': '12',
#    'missing': '0',
#    'min': '2',
#    'max': '14',
#    'mean': '7',
#    'stdev': '2'},
#   {'name': 'Functional',
#    'index': '55',
#    'type': 'string',
#    'distinct': '7',
#    'missing': '0'},
#   {'name': 'Fireplaces',
#    'index': '56',
#    'type': 'numeric',
#    'distinct': '4',
#    'missing': '0',
#    'min': '0',
#    'max': '3',
#    'mean': '1',
#    'stdev': '1'},
#   {'name': 'FireplaceQu',
#    'index': '57',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '690'},
#   {'name': 'GarageType',
#    'index': '58',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '81'},
#   {'name': 'GarageYrBlt',
#    'index': '59',
#    'type': 'numeric',
#    'distinct': '97',
#    'missing': '81',
#    'min': '1900',
#    'max': '2010',
#    'mean': '1979',
#    'stdev': '25'},
#   {'name': 'GarageFinish',
#    'index': '60',
#    'type': 'string',
#    'distinct': '3',
#    'missing': '81'},
#   {'name': 'GarageCars',
#    'index': '61',
#    'type': 'numeric',
#    'distinct': '5',
#    'missing': '0',
#    'min': '0',
#    'max': '4',
#    'mean': '2',
#    'stdev': '1'},
#   {'name': 'GarageArea',
#    'index': '62',
#    'type': 'numeric',
#    'distinct': '441',
#    'missing': '0',
#    'min': '0',
#    'max': '1418',
#    'mean': '473',
#    'stdev': '214'},
#   {'name': 'GarageQual',
#    'index': '63',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '81'},
#   {'name': 'GarageCond',
#    'index': '64',
#    'type': 'string',
#    'distinct': '5',
#    'missing': '81'},
#   {'name': 'PavedDrive',
#    'index': '65',
#    'type': 'string',
#    'distinct': '3',
#    'missing': '0'},
#   {'name': 'WoodDeckSF',
#    'index': '66',
#    'type': 'numeric',
#    'distinct': '274',
#    'missing': '0',
#    'min': '0',
#    'max': '857',
#    'mean': '94',
#    'stdev': '125'},
#   {'name': 'OpenPorchSF',
#    'index': '67',
#    'type': 'numeric',
#    'distinct': '202',
#    'missing': '0',
#    'min': '0',
#    'max': '547',
#    'mean': '47',
#    'stdev': '66'},
#   {'name': 'EnclosedPorch',
#    'index': '68',
#    'type': 'numeric',
#    'distinct': '120',
#    'missing': '0',
#    'min': '0',
#    'max': '552',
#    'mean': '22',
#    'stdev': '61'},
#   {'name': '3SsnPorch',
#    'index': '69',
#    'type': 'numeric',
#    'distinct': '20',
#    'missing': '0',
#    'min': '0',
#    'max': '508',
#    'mean': '3',
#    'stdev': '29'},
#   {'name': 'ScreenPorch',
#    'index': '70',
#    'type': 'numeric',
#    'distinct': '76',
#    'missing': '0',
#    'min': '0',
#    'max': '480',
#    'mean': '15',
#    'stdev': '56'},
#   {'name': 'PoolArea',
#    'index': '71',
#    'type': 'numeric',
#    'distinct': '8',
#    'missing': '0',
#    'min': '0',
#    'max': '738',
#    'mean': '3',
#    'stdev': '40'},
#   {'name': 'PoolQC',
#    'index': '72',
#    'type': 'string',
#    'distinct': '3',
#    'missing': '1453'},
#   {'name': 'Fence',
#    'index': '73',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '1179'},
#   {'name': 'MiscFeature',
#    'index': '74',
#    'type': 'string',
#    'distinct': '4',
#    'missing': '1406'},
#   {'name': 'MiscVal',
#    'index': '75',
#    'type': 'numeric',
#    'distinct': '21',
#    'missing': '0',
#    'min': '0',
#    'max': '15500',
#    'mean': '43',
#    'stdev': '496'},
#   {'name': 'MoSold',
#    'index': '76',
#    'type': 'numeric',
#    'distinct': '12',
#    'missing': '0',
#    'min': '1',
#    'max': '12',
#    'mean': '6',
#    'stdev': '3'},
#   {'name': 'YrSold',
#    'index': '77',
#    'type': 'numeric',
#    'distinct': '5',
#    'missing': '0',
#    'min': '2006',
#    'max': '2010',
#    'mean': '2008',
#    'stdev': '1'},
#   {'name': 'SaleType',
#    'index': '78',
#    'type': 'string',
#    'distinct': '9',
#    'missing': '0'},
#   {'name': 'SaleCondition',
#    'index': '79',
#    'type': 'string',
#    'distinct': '6',
#    'missing': '0'}],
#  'nr_of_issues': 0,
#  'nr_of_downvotes': 0,
#  'nr_of_likes': 2,
#  'nr_of_downloads': 7,
#  'total_downloads': 30,
#  'reach': 9,
#  'reuse': 8,
#  'impact_of_reuse': 0,
#  'reach_of_reuse': 0,
#  'impact': 8}
