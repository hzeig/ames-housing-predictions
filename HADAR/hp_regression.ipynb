# %% [markdown]
# # House Price Data Analysis

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression, HuberRegressor, Ridge, Lasso, ElasticNet, LinearRegression
# from sklearn.

# %%
# read in data
housePrice = pd.read_csv('HousePrice_encoded.csv', index_col='PID')

# %% [markdown]
# ## $Supervised$

# %% [markdown]
# # Linear Regressions
# ### Simple, Multiple, Logistic, Penalized
#
# **Purpose:** Testing out methods from class

# %% [markdown]
# #### Simple Linear Regression

# %% [markdown]
# ### Groups / Clusters

# %%
# group features
date = housePrice.filter(regex='Yr|Mo|Year')
location = housePrice.filter(regex='Neighborhood') # not actually useful -- just to not forget about this feature
style = housePrice.filter(regex='Style|BldgType')
area = housePrice.filter(regex='SF|Area')
lot_land = housePrice.filter(regex= 'Lot|Land')
street = housePrice.filter(regex='Street|Alley')
basement = housePrice.filter(regex='Bsmt')
garage = housePrice.filter(regex='Garage|Drive')
rooms = housePrice.filter(regex='Bed|Bath|Rms|Kitc|')
outdoor = housePrice.filter(regex='Deck|Porch|Pool|Exter|Roof|MasnVnr')
energy = housePrice.filter(regex='Util|Heat|Air|Electric')
sale = housePrice.filter(regex='Sale')
quality = housePrice.filter(regex='Qual')
condition = housePrice.filter(regex='Cond')

# %% [markdown]
# #### Multiple Linear Regression

# %%
date.hist(bins=30, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'YearRemodAdd'}>],
#        [<AxesSubplot:title={'center':'GarageYrBlt'}>,
#         <AxesSubplot:title={'center':'MoSold'}>],
#        [<AxesSubplot:title={'center':'YrSold'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Logistic Regression

# %% [markdown]
# ### Feature Selection with Lasso

# %% [markdown]
# ## $Unsupervised$

# %% [markdown]
# ### Association Nets
